# %%
import random
import wandb

for n_units in [1, 2, 3]:
    wandb.init(project="delete-this", config={"n_units": n_units}, reinit=True)
    for epoch_i in [1, 2, 3, 4, 5]:
        wandb.log({"train/loss": epoch_i * 100 - random.randint(-10, 10)}, step=epoch_i)
        wandb.log({"valid/loss": epoch_i * 100 - random.randint(-20, 20)}, step=epoch_i)
    wandb.log({
        "test/loss": n_units * 10 - random.randint(-5, 5),
    })
# Out:
# Finishing last run (ID:pomwl3hq) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/loss</td><td>▁</td></tr><tr><td>train/loss</td><td>▁▃▄▆█</td></tr><tr><td>valid/loss</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/loss</td><td>26</td></tr><tr><td>train/loss</td><td>490</td></tr><tr><td>valid/loss</td><td>516</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">radiant-flower-3</strong> at: <a href='https://wandb.ai/anony-moose-511077/delete-this/runs/pomwl3hq?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this/runs/pomwl3hq?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230316_200018-pomwl3hq/logs</code>
# Successfully finished last run (ID:pomwl3hq). Initializing new run:<br/>
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/huyentn2/project/nano_count/segmentation_unet/wandb/run-20230316_200037-arz08jb0</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-511077/delete-this/runs/arz08jb0?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">breezy-universe-4</a></strong> to <a href='https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a>
#  View run at <a href='https://wandb.ai/anony-moose-511077/delete-this/runs/arz08jb0?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this/runs/arz08jb0?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# Finishing last run (ID:arz08jb0) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/loss</td><td>▁</td></tr><tr><td>train/loss</td><td>▁▃▅▆█</td></tr><tr><td>valid/loss</td><td>▁▃▄▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/loss</td><td>9</td></tr><tr><td>train/loss</td><td>510</td></tr><tr><td>valid/loss</td><td>519</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">breezy-universe-4</strong> at: <a href='https://wandb.ai/anony-moose-511077/delete-this/runs/arz08jb0?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this/runs/arz08jb0?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230316_200037-arz08jb0/logs</code>
# Successfully finished last run (ID:arz08jb0). Initializing new run:<br/>
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/huyentn2/project/nano_count/segmentation_unet/wandb/run-20230316_200043-u863571k</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-511077/delete-this/runs/u863571k?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">fine-snow-5</a></strong> to <a href='https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a>
#  View run at <a href='https://wandb.ai/anony-moose-511077/delete-this/runs/u863571k?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this/runs/u863571k?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# Finishing last run (ID:u863571k) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/loss</td><td>▁</td></tr><tr><td>train/loss</td><td>▁▃▅▆█</td></tr><tr><td>valid/loss</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/loss</td><td>20</td></tr><tr><td>train/loss</td><td>491</td></tr><tr><td>valid/loss</td><td>498</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fine-snow-5</strong> at: <a href='https://wandb.ai/anony-moose-511077/delete-this/runs/u863571k?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this/runs/u863571k?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230316_200043-u863571k/logs</code>
# Successfully finished last run (ID:u863571k). Initializing new run:<br/>
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/huyentn2/project/nano_count/segmentation_unet/wandb/run-20230316_200050-hpw5sohd</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-511077/delete-this/runs/hpw5sohd?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">still-river-6</a></strong> to <a href='https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a>
#  View run at <a href='https://wandb.ai/anony-moose-511077/delete-this/runs/hpw5sohd?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32' target="_blank">https://wandb.ai/anony-moose-511077/delete-this/runs/hpw5sohd?apiKey=82bab5966c865a4001b8aa9e9bf8426139366d32</a>
# Do NOT share these links with anyone. They can be used to claim your runs.

# %%
'Loss at epoch {}: {}'.format(0, 1000)
# Out:
# 'Loss at epoch 0: 1000'

# %%
import pdb
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt



input_dir = "/home/huyentn2/project/nano_count/segmentation_unet/data/img_patch/Tianle1ng_0208_2.png"
im = Image.open(input_dir)
img = np.array(im)

# %%
plt.imshow(img, cmap ='gray')

# %%
plt.imsave('DR.png', img, cmap='gray')
